# %%
import os
import pandas as pd
from collections.abc import Iterable
#from collections.abc import Iterable
from datetime import date, timedelta, datetime
from python_vlookup import python_vlookup
import numpy as np

#Velocity/S4 file date and DB update date
# ontem = date.today() - timedelta()
# update_date = ontem + timedelta()
update_date = date.today() - timedelta(1)
month = update_date.strftime('%Y_%m')
# data_csv_OARs = ontem.strftime('%Y%m%d')
update_date = update_date.strftime('%Y-%m-%d')
data_csv_Webi = update_date

# Read DETAILS      
string1 = "WW_INVENTORY_DETAIL"
string2 = ".csv"
leitura = string1 + string2 
    
os.chdir('C:/Users/bmma/OneDrive - HP Inc/LATAM Inventory/Imported OARs Daily Files/Extração OARs/')
base = pd.read_csv(leitura, sep = ',', encoding = 'latin-1', low_memory = False)
#base = pd.read_csv(filename, sep = ',', encoding = 'latin-1', low_memory = False)

#Remove Last Day of previous month and fix dates
base['REFERENCE_DT'] = pd.to_datetime(base['REFERENCE_DT'], format='%d-%b-%y')

###########TEMPORARY CHANGE until Nov23rd/21
#base['REFERENCE_DT'] = pd.to_datetime(base['REFERENCE_DT'], format='%m/%d/%Y')
###########TEMPORARY CHANGE until Nov23rd/21

# first = ontem.replace(day=1)
# lastMonth = first - timedelta(days=1)
# lastMonth = lastMonth.strftime('%d-%b-%y').upper()
# lastMonth = lastMonth.strftime('%d-%b-%y').upper()

# base = base[base.REFERENCE_DT!='30-MAR-21']

lastMonth = min(base.REFERENCE_DT)
base = base[base.REFERENCE_DT!=lastMonth]

base['REFERENCE_DT'] = base['REFERENCE_DT'] + timedelta()

#Format Date column as Date 
base['REFERENCE_DT'] = pd.to_datetime(base['REFERENCE_DT'], format='%d-%b-%y')

#Remove regions from DETAILS
Remove_Region = ['US','CA','EU','AP','??']
base = base[base.REGION_CD.isin(Remove_Region) == False]

# Remove all S4 data from DETAILS
Remove_S4 = ['US42','US46','US74','PR50','AR01','AR19','AR20','PA20','PA21',
             'PA22','PA60','PA61','PA62','PA65','PA66','PA68','PA69','PA70',
             'PA71','PA72','PA73','PA74','PA76','PA77','PA78','PA79','PA80',
             'PA81','US38','PA75','BR01','BR19','BR20','BR21','BR22','BR24',
             'BR25','CA01','CA19','CA20','CA21','CA22','CA23','CA24','US21',
             'US51','US60','US61','US65','US66','US68','US69','US70','US71',
             'US72','US73','US76','US77','US79','US81','US82','CL01','CL19',
             'CL20','CO01','CO19','CO20','MX01','MX19','MX21','MX20','MX22',
             'MX23','MX24','MX61','PR20','US50','PE01','PE19','PE20','PR01',
             'US01','US22','US23','US24','US25','US26','US27','US28','US29',
             'US30','US31','US32','US33','US34','US35','US36','US37','US38',
             'US39','US40','US62','US63','US64','US67','US74','US78','US80',
             'WW01','US87','US20','USZ0','US02'] # adiconado 'PR50' Puerto Rico ???
base = base[base.LOCATION_CD.isin(Remove_S4) == False] 

# Remove not used plants from DETAILS
Remove_CD = ['3602','00EK','00EL','01AC','01AD','DV01','S710','AL03','H5V2',
             'H5V3','JK02','N103','PR20','US62','R603', '10PA', '11CO', '11CL',
             '11AR']
base = base[base.LOCATION_CD.isin(Remove_CD) == False]

# Delete not used Columns from DETAILS
base.drop([
'LOCAL_STD_COST_AM','ISO_CURRENCY_CD','CURRENCY_RATE','USD_STD_COST_AM',
'PROD_LINE_NM','PROD_TECHNOLOGY_NM','PLTFRM_SUBSET_GRP_NM','PLTFRM_SUBSET_NM',
'LOCAL_INV_DOLLARS','REFERENCE_DT','BUS_UNIT_NM','ZERO_INV_QT_FL','BASE_PROD_NM',
'CONTROLLER_ID','SOURCE_ENTITY_CD','REFURB_FL','FIRST_NM','STREET_ADDR_TX',
'CITY_NM','POSTAL_CD','COUNTRY_REGION_CD','PROD_CLASS_NM','PROD_TYPE_NM',
'FIN_MKT_CAT_NM','PROD_SEG_NM','PROD_CLASS_CD','PROD_PLTFRM_NM','PH_ITEM_DN',
'PH_LEVEL_05_CD','PH_LEVEL_05_DN','PH_PRODUCT_CATEGORY_GROUP','PH_PRODUCT_TYPE',
'BASE_PROD_NR','SELECTABILITY_CD','INTRO_DT','DISCO_DT','EOL_DT','LC_STAT_CD',
'OBSOLETE_DT','SOURCE_PART_NR','PRODUCT_MODEL_NR','4_Month_Risk','5_Month_Risk',
'6_Month_Risk','7_Month_Risk','8_Month_Risk','9_Month_Risk','10_Month_Risk',
'Aging_Risk_QT','Aging_Risk_Pct','Aging_Risk_Am','FILE_SENDER_ID','WEIGHT',
'LOCATION_NM','IN_TRANSIT_DEPOT_QT','AWAITING_DISP_QT','IN_PROCESS_QT',
'IN_REWORK_QT','AVAILABLE_QT','IN_INSPECTION_QT','CONSIGNED_QT','REGION_CD',
'STORAGE_LOCATION_DN','COUNTRY_CD','EXTERNAL_SEGMENT_DN','EXTRACT_TS'],
inplace=True, axis=1,errors='ignore')

###########TEMPORARY CHANGE until Nov23rd/21
# base.drop(['ï»¿PRINTER_FL', 'BA_PRODUCT_CATEGORY_DN', 'BA_PRODUCT_LINE_DN',
#            'BUS_UNIT_NM-1', 'Table Names'], inplace=True, axis=1,errors='ignore')

# base = base[['SALES_PROD_W_OPTION_NR','PART_DN','PRODUCT_LINE_CD','PROD_FAMILY_NM',
#              'LOCATION_CD','INV_QT','USD_INV_DOLLARS','REGION_OWNER','FGI_FL',
#              'STORAGE_LOCATION_CD','PROD_CAT_NM','PRODUCT_SUBGROUP_DN','PH_PRODUCT_TYPE_NM',
#              'AGE_0_30_QT','AGE_0_30_AM','AGE_31_37_QT','AGE_31_37_AM','AGE_38_44_QT',
#              'AGE_38_44_AM','AGE_45_60_QT','AGE_45_60_AM','AGE_61_90_QT','AGE_61_90_AM',
#              'AGE_91_120_QT','AGE_91_120_AM','AGE_121_180_QT','AGE_121_180_AM',
#              'AGE_181_QT','AGE_181_AM','AGE_NO_RECEIPT_QT','AGE_NO_RECEIPT_AM',]]
###########TEMPORARY CHANGE until Nov23rd/21

# New columns from Webi
base['Age 0-7 Qt'] = ""
base['Age 8-14 Qt'] = ""
base['Age 15-21 Qt'] = ""
base['Age 22-28 Qt'] = ""
base['Age 29-35 Qt'] = ""
base['Age 36-42 Qt'] = ""
base['Age 43-49 Qt'] = ""
base['Age 50-56 Qt'] = ""
base['Age 57-63 Qt'] = ""
base['Age 64-70 Qt'] = ""
base['Age 71-77 Qt'] = ""
base['Age 78-84 Qt'] = ""
base['Age 85-90 Qt'] = ""
base['Age 121-150 Qt'] = ""
base['Age 151-180 Qt'] = ""
base['Age 181-210 Qt'] = ""
base['Age 211-240 Qt'] = ""
base['Age 241-270 Qt'] = ""
base['Age 271-300 Qt'] = ""
base['Age 301-330 Qt'] = ""
base['Age 331-360 Qt'] = ""
base['Age Greater 360 Qt'] = ""
base['Age 0-7 Am'] = ""
base['Age 8-14 Am'] = ""
base['Age 15-21 Am'] = ""
base['Age 22-28 Am'] = ""
base['Age 29-35 Am'] = ""
base['Age 36-42 Am'] = ""
base['Age 43-49 Am'] = ""
base['Age 50-56 Am'] = ""
base['Age 57-63 Am'] = ""
base['Age 64-70 Am'] = ""
base['Age 71-77 Am'] = ""
base['Age 78-84 Am'] = ""
base['Age 85-90 Am'] = ""
base['Age 121-150 Am'] = ""
base['Age 151-180 Am'] = ""
base['Age 181-210 Am'] = ""
base['Age 211-240 Am'] = ""
base['Age 241-270 Am'] = ""
base['Age 271-300 Am'] = ""
base['Age 301-330 Am'] = ""
base['Age 331-360 Am'] = ""
base['Age Greater 360 Am'] = ""
base['LAST60_SHIP_QT'] = ""
base['LAST90_SHIP_QT'] = ""
base['Last Receipt Dt'] = ""

#New webi version 4.0 removed 31-37/38-45/46-60
base['AGE_31_60_QT'] = base['AGE_31_37_QT']+base['AGE_38_44_QT']+base['AGE_45_60_QT']
base['AGE_31_60_AM'] = base['AGE_31_37_AM']+base['AGE_38_44_AM']+base['AGE_45_60_AM']

# Read WEBI
string3 = "WEBI_"
string4 = ".xlsx"
leitura2 = string3 + data_csv_Webi + string4 
os.chdir('C:/Users/bmma/OneDrive - HP Inc/LATAM Inventory/Imported OARs Daily Files/Webi_41/')
base_webi = pd.read_excel(leitura2, sheet_name="Inventory Age Analysis (Weekly ", header=2)
base_webi.loc[pd.isnull(base_webi['Material Profit Center Cd'])]

#base_webi['Last Receipt Dt'].dtypes
#base_webi['Last Receipt Dt'] = pd.to_datetime(base_webi['Last Receipt Dt'], format='%Y-%m-%d')
base_webi['Last Receipt Dt'] = pd.to_datetime(base_webi['Last Receipt Dt']).dt.date

# Remove US S4 Plants from WEBI
Remove_S4_US = ['US42','US46','US74','PR50','PA65','PA66','PA69','US62','US21',
                'US64','US40','CA23','US65','US66','US68','US83','US49','CA22',
                'US67','CA20','US69','US26','CA21','US61','US51','US60','US63',
                'US25','US85','US79','US76','US50','PR20','US24','US71','PA68',
                'PA76','PA21','US22','US23','US27']
base_webi = base_webi[base_webi['Plant Cd'].isin(Remove_S4_US) == False]

#PL code removing last string code
base_webi['Material Profit Center Cd'] = base_webi['Material Profit Center Cd'].astype(str).str[:-2]
base_webi['Material Profit Center Cd'] = base_webi['Material Profit Center Cd'].astype(str).str[1:]

#Product type unification

base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'UNIT')] = 'Units'
base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'CTO MODULE')] = 'Config Module'
base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'OPTION')] = 'Options'
base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd']== 'BASE')] = 'Options'
#base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'SR')] = 'Third Party'
base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'THIRD PARTY')] = 'Third Party'
#base_webi['External Material Group Cd'].loc[(base_webi['External Material Group Cd'] == 'NONE')] = ''

#Fill Description (Temporaly due to Webi 4.0)
#lookup_value = pd.array(base_webi['Material Nr'])
#base_webi['Hierarchy Model Node Dn'] = python_vlookup.vlookup(lookup_value,'SKU Description.csv',4 ,debug='skip', error_value="")

# Delete not used Columns from WEBI
base_webi = base_webi.drop(base_webi.columns[0],axis=1)
base_webi.drop(['Reference Dt','Reference Timestamp (GMT)','Company Cd','Plant Nm','Plant City Nm',
                'Storage Location Description','Profit Center Hier  Level2 Dn',
                'Profit Center Hier  Level3 Dn', 'Profit Center Hier  Level4 Dn',
                'Profit Center Hier  Level6 Dn', 'Hierarchy Type Node Dn',
                'Hierarchy SubCategory Node Dn','Hierarchy BigSeries Node Dn',
                'Hierarchy Series Node Dn','Hierarchy Model Node Dn',
                'Material Type Cd', 'Feature Type Cd','Material Group Cd',
                'Material Commodity Cd', 'New or Used Material Cd',
                'Material Product Announcement Dt','Material Selective Availability Dt',
                'Material General Availability Dt','Material End Of Life Dt',
                'Material Discontinued Dt','Material Marketing Obsolete Dt',
                'Material Support Obsolete Dt','Last Shipped Dt',
                'Material Std Cost USD Am','Material Std Cost LC Am',                           
                ],
               inplace=True, axis=1, errors='ignore')

# Consolidate +121 days age buckets from WEBI
base_webi['AGE_121_180_QT'] = base_webi['Age 121-150 Qt'] + base_webi['Age 151-180 Qt']
base_webi['AGE_121_180_AM'] = base_webi['Age 121-150 Am'] + base_webi['Age 151-180 Am']

Rest_Col_QT = ['Age 181-210 Qt', 'Age 211-240 Qt', 'Age 241-270 Qt', 'Age 271-300 Qt',
               'Age 301-330 Qt', 'Age 331-360 Qt', 'Age Greater 360 Qt']

Rest_Col_AM = ['Age 181-210 Am', 'Age 211-240 Am', 'Age 241-270 Am', 'Age 271-300 Am',
               'Age 301-330 Am', 'Age 331-360 Am', 'Age Greater 360 Am']

base_webi['AGE_181_QT'] = base_webi[Rest_Col_QT].sum(axis=1)
base_webi['AGE_181_AM'] = base_webi[Rest_Col_AM].sum(axis=1)

#base_webi = base_webi.drop(['Age 121-150 Qt', 'Age 151-180 Qt', 'Age 121-150 Am', 
#                            'Age 151-180 Am'],axis=1)

#base_webi = base_webi.drop(['Age 181-210 Qt', 'Age 211-240 Qt', 'Age 241-270 Qt', 'Age 271-300 Qt',
#               'Age 301-330 Qt', 'Age 331-360 Qt', 'Age Greater 360 Qt'],axis=1)
#base_webi = base_webi.drop(['Age 181-210 Am', 'Age 211-240 Am', 'Age 241-270 Am', 'Age 271-300 Am',
#               'Age 301-330 Am', 'Age 331-360 Am', 'Age Greater 360 Am'],axis=1)

# Add columns to WEBI dataframe to match details
base_webi['FGI_FL'] = ""
#base_webi['PROD_FAMILY_NM'] = "" Webi 4.0 added platform (family) name
# Webi 4.0 do not have these below buckets anymore
base_webi['AGE_31_37_QT'] = "" 
base_webi['AGE_31_37_AM'] = ""
base_webi['AGE_38_44_QT'] = ""
base_webi['AGE_38_44_AM'] = ""
base_webi['AGE_45_60_QT'] = ""
base_webi['AGE_45_60_AM'] = ""

#Adding Region Onwer to Webi data
base_webi['Storage Location Cd'] = base_webi['Storage Location Cd'].fillna("")
base_webi['Concatenado'] = base_webi['Plant Cd'].astype(str) + base_webi['Storage Location Cd'].astype(str)
base_webi['Concatenado'].loc[(base_webi['Concatenado'].str.len() > 4)] = base_webi['Concatenado'].loc[(base_webi['Concatenado'].str.len() > 4)].astype(str).str[:-2]

lookup_value = pd.array(base_webi['Concatenado'])
base_webi['REGION_OWNER'] = python_vlookup.vlookup(lookup_value,'Storage Location.csv',6 ,debug='skip', error_value="")

base_webi.drop(['Concatenado'],inplace=True, axis=1)

# Reorder columns from WEBI dataframe to match DETAILS
base_webi = base_webi[['Material Nr','Material Dn','Material Profit Center Cd','Platform Nm','Plant Cd',
                       'On Hand Total Inventory Qt','On Hand Total Inventory Am',
                       'REGION_OWNER','FGI_FL','Storage Location Cd','Profit Center Hier  Level5 Dn',
                       'Hierarchy Category Node Dn','External Material Group Cd',
                       'Age 0-30 Qt','Age 0-30 Am','AGE_31_37_QT','AGE_31_37_AM',
                       'AGE_38_44_QT','AGE_38_44_AM','AGE_45_60_QT',
                       'AGE_45_60_AM','Age 61-90 Qt','Age 61-90 Am',
                       'Age 91-120 Qt','Age 91-120 Am','AGE_121_180_QT',
                       'AGE_121_180_AM','AGE_181_QT','AGE_181_AM',
                       'Age No Receipt Qt','Age No Receipt Am',
                       'Age 0-7 Qt','Age 8-14 Qt','Age 15-21 Qt','Age 22-28 Qt',
                       'Age 29-35 Qt','Age 36-42 Qt','Age 43-49 Qt','Age 50-56 Qt',
                       'Age 57-63 Qt','Age 64-70 Qt','Age 71-77 Qt','Age 78-84 Qt',
                       'Age 85-90 Qt','Age 121-150 Qt',
                       'Age 151-180 Qt','Age 181-210 Qt','Age 211-240 Qt',
                       'Age 241-270 Qt','Age 271-300 Qt','Age 301-330 Qt',
                       'Age 331-360 Qt','Age Greater 360 Qt','Age 0-7 Am','Age 8-14 Am',
                       'Age 15-21 Am','Age 22-28 Am','Age 29-35 Am','Age 36-42 Am',
                       'Age 43-49 Am','Age 50-56 Am','Age 57-63 Am','Age 64-70 Am',
                       'Age 71-77 Am','Age 78-84 Am','Age 85-90 Am',
                       'Age 121-150 Am','Age 151-180 Am','Age 181-210 Am',
                       'Age 211-240 Am','Age 241-270 Am','Age 271-300 Am','Age 301-330 Am',
                       'Age 331-360 Am','Age Greater 360 Am',
                       'Last 60 Days Shipment Qt','Last 90 Days Shipment Qt','Last Receipt Dt',
                       'Age 31-60 Qt','Age 31-60 Am']]          
  
# Rename columns from WEBI dataframe to match details
base_webi.columns = [
'SALES_PROD_W_OPTION_NR',
'PART_DN',
'PRODUCT_LINE_CD',
'PROD_FAMILY_NM',
'LOCATION_CD',
'INV_QT',
'USD_INV_DOLLARS',
'REGION_OWNER',
'FGI_FL',
'STORAGE_LOCATION_CD',
'PROD_CAT_NM',
'PRODUCT_SUBGROUP_DN',
'PH_PRODUCT_TYPE_NM',
'AGE_0_30_QT',
'AGE_0_30_AM',
'AGE_31_37_QT',
'AGE_31_37_AM',
'AGE_38_44_QT',
'AGE_38_44_AM',
'AGE_45_60_QT',
'AGE_45_60_AM',
'AGE_61_90_QT',
'AGE_61_90_AM',
'AGE_91_120_QT',
'AGE_91_120_AM',
'AGE_121_180_QT',
'AGE_121_180_AM',
'AGE_181_QT',
'AGE_181_AM',
'AGE_NO_RECEIPT_QT',
'AGE_NO_RECEIPT_AM',
'Age 0-7 Qt','Age 8-14 Qt','Age 15-21 Qt','Age 22-28 Qt',
'Age 29-35 Qt','Age 36-42 Qt','Age 43-49 Qt','Age 50-56 Qt',
'Age 57-63 Qt','Age 64-70 Qt','Age 71-77 Qt','Age 78-84 Qt',
'Age 85-90 Qt','Age 121-150 Qt',
'Age 151-180 Qt','Age 181-210 Qt','Age 211-240 Qt',
'Age 241-270 Qt','Age 271-300 Qt','Age 301-330 Qt',
'Age 331-360 Qt','Age Greater 360 Qt','Age 0-7 Am','Age 8-14 Am',
'Age 15-21 Am','Age 22-28 Am','Age 29-35 Am','Age 36-42 Am',
'Age 43-49 Am','Age 50-56 Am','Age 57-63 Am','Age 64-70 Am',
'Age 71-77 Am','Age 78-84 Am','Age 85-90 Am',
'Age 121-150 Am','Age 151-180 Am','Age 181-210 Am',
'Age 211-240 Am','Age 241-270 Am','Age 271-300 Am','Age 301-330 Am',
'Age 331-360 Am','Age Greater 360 Am',
'LAST60_SHIP_QT',
'LAST90_SHIP_QT',
'Last Receipt Dt',
'AGE_31_60_QT',
'AGE_31_60_AM',
]

#Unifying extrnal segment descriptions         
#base_webi.loc[base_webi.EXTERNAL_SEGMENT_DN == 'PERSONAL SYSTEMS GROUP', 'EXTERNAL_SEGMENT_DN'] = 'Personal Systems'
#base_webi.loc[base_webi.EXTERNAL_SEGMENT_DN == 'IMAGING AND PRINTING GROUP', 'EXTERNAL_SEGMENT_DN'] = 'Printing'

#Temporary fix for blank PL
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'Q6002A')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'W2000XC')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'W9020MC')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'W9022MC')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'W9023MC')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == 'W9021MC')] = 'GJ'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == '3YM78AL')] = '1N'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == '3YM80AL')] = '1N'
#base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == '6FW07A#AKV')] = '4X'
#base_webi['STORAGE_LOCATION_CD'].loc[(base_webi['STORAGE_LOCATION_CD'] == '')] = '1001'
base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == '2TB68A4#ABA')] = 'TB'
base_webi['PRODUCT_LINE_CD'].loc[(base_webi['SALES_PROD_W_OPTION_NR'] == '4VW57AA')] = 'IQ'

# Merge Velocity and S4
#base_pos_merge = pd.DataFrame(pd.concat([base, base_webi]))
base_pos_merge = pd.DataFrame(pd.concat([base, base_webi], ignore_index=True))

#Temporary fix for blank PL
base_pos_merge['PRODUCT_LINE_CD'].loc[(base_pos_merge['SALES_PROD_W_OPTION_NR'] == '2RQ08B  #B1K')] = 'GE'
base_pos_merge['PRODUCT_LINE_CD'].loc[(base_pos_merge['SALES_PROD_W_OPTION_NR'] == 'A7K23LT #ABM')] = '6U'

# New Columns for SQL Database
base_pos_merge['Aging'] = ""
base_pos_merge['Business Group'] = ""
base_pos_merge['Region'] = ""
base_pos_merge['Country Plant'] = ""
base_pos_merge['Category'] = ""
base_pos_merge['Month'] =""
base_pos_merge['Quarter'] = ""
base_pos_merge['Material Class'] = ""
base_pos_merge['Ag_Avrg'] = ""
base_pos_merge['Update_Date'] = update_date
#base_pos_merge['AGE_181_240_QT'] = ""
#base_pos_merge['AGE_181_240_AM'] = ""
#base_pos_merge['AGE_241_360_QT'] = ""
#base_pos_merge['AGE_241_360_AM'] = ""
#base_pos_merge['AGE_361_QT'] = ""

#base_pos_merge['AGE_361_AM'] = ""

#Change Column names for SQL Database
base_pos_merge.columns = ['Material', 'Material Description' , 'PL',
                          'PROD_FAMILY_NM','Plant', 'Qty', 'Cost',
                          'Country', 'Category3', 'StorageLoc',
                          'PROD_CAT_NM', 'Family Desc','Category2',
                          'AGE_0_30_QT', 'AGE_0_30_AM', 'AGE_31_37_QT',
                          'AGE_31_37_AM','AGE_38_44_QT', 'AGE_38_44_AM',
                          'AGE_45_60_QT', 'AGE_45_60_AM', 'AGE_61_90_QT',
                          'AGE_61_90_AM', 'AGE_91_120_QT', 'AGE_91_120_AM',
                          'AGE_121_180_QT', 'AGE_121_180_AM', 'AGE_181_QT',
                          'AGE_181_AM', 'AGE_NO_RECEIPT_QT',
                          'AGE_NO_RECEIPT_AM',
                          'Age 0-7 Qt','Age 8-14 Qt','Age 15-21 Qt','Age 22-28 Qt',
                          'Age 29-35 Qt','Age 36-42 Qt','Age 43-49 Qt','Age 50-56 Qt',
                          'Age 57-63 Qt','Age 64-70 Qt','Age 71-77 Qt','Age 78-84 Qt',
                          'Age 85-90 Qt','Age 121-150 Qt',
                          'Age 151-180 Qt','Age 181-210 Qt','Age 211-240 Qt',
                          'Age 241-270 Qt','Age 271-300 Qt','Age 301-330 Qt',
                          'Age 331-360 Qt','Age Greater 360 Qt','Age 0-7 Am','Age 8-14 Am',
                          'Age 15-21 Am','Age 22-28 Am','Age 29-35 Am','Age 36-42 Am',
                          'Age 43-49 Am','Age 50-56 Am','Age 57-63 Am','Age 64-70 Am',
                          'Age 71-77 Am','Age 78-84 Am','Age 85-90 Am',
                          'Age 121-150 Am','Age 151-180 Am','Age 181-210 Am',
                          'Age 211-240 Am','Age 241-270 Am','Age 271-300 Am','Age 301-330 Am',
                          'Age 331-360 Am','Age Greater 360 Am',
                          'Last 60 Days Shipment Qt',
                          'Last 90 Days Shipment Qt','Last Receipt Dt',
                          'AGE_31_60_QT','AGE_31_60_AM',
                          'Aging', 'Business Group', 'Region',
                          'Country Plant','Category','Month', 'Quarter',
                          'Material Class','Ag_Avrg','Update_Date']

#Reorder Column names for SQL Database
base_pos_merge = base_pos_merge[['Aging', 'Update_Date' , 'Month', 'Quarter',
                         'Region', 'Country', 'Country Plant', 'Business Group',
                         'Category', 'Category2', 'Category3', 'StorageLoc',
                         'PL', 'Material', 'Qty', 'Cost',
                         'Ag_Avrg','Material Description','PROD_FAMILY_NM',
                         'Family Desc','Material Class',
                         'Plant', 'AGE_0_30_QT', 'AGE_0_30_AM', 'AGE_31_37_QT', 
                         'AGE_31_37_AM','AGE_38_44_QT', 'AGE_38_44_AM',
                         'AGE_45_60_QT', 'AGE_45_60_AM','AGE_31_60_QT','AGE_31_60_AM',
                         'AGE_61_90_QT','AGE_61_90_AM', 'AGE_91_120_QT', 'AGE_91_120_AM',
                         'AGE_121_180_QT', 'AGE_121_180_AM', 'AGE_181_QT',
                         'AGE_181_AM','AGE_NO_RECEIPT_QT', 'AGE_NO_RECEIPT_AM',
                         'Age 0-7 Qt','Age 8-14 Qt','Age 15-21 Qt','Age 22-28 Qt',
                         'Age 29-35 Qt','Age 36-42 Qt','Age 43-49 Qt','Age 50-56 Qt',
                         'Age 57-63 Qt','Age 64-70 Qt','Age 71-77 Qt','Age 78-84 Qt',
                         'Age 85-90 Qt','Age 121-150 Qt',
                         'Age 151-180 Qt','Age 181-210 Qt','Age 211-240 Qt',
                         'Age 241-270 Qt','Age 271-300 Qt','Age 301-330 Qt',
                         'Age 331-360 Qt','Age Greater 360 Qt','Age 0-7 Am','Age 8-14 Am',
                         'Age 15-21 Am','Age 22-28 Am','Age 29-35 Am','Age 36-42 Am',
                         'Age 43-49 Am','Age 50-56 Am','Age 57-63 Am','Age 64-70 Am',
                         'Age 71-77 Am','Age 78-84 Am','Age 85-90 Am',
                         'Age 121-150 Am','Age 151-180 Am','Age 181-210 Am',
                         'Age 211-240 Am','Age 241-270 Am','Age 271-300 Am','Age 301-330 Am',
                         'Age 331-360 Am','Age Greater 360 Am',      
                         'PROD_CAT_NM', 'Last 60 Days Shipment Qt',
                         'Last 90 Days Shipment Qt','Last Receipt Dt']]

#Region Classification (Physical Location = CDO)
## Added new plant BR18 on 06--6-2023 - Requested by Francisco
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'H509') | (base_pos_merge['Plant'] == 'H5V1') | 
        (base_pos_merge['Plant'] == 'Z402') | (base_pos_merge['Plant'] == 'BR18')] = 'BR'
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == '9401') | (base_pos_merge['Plant'] == 'AL01') | 
        (base_pos_merge['Plant'] == 'B301') | (base_pos_merge['Plant'] == 'H503') |
        (base_pos_merge['Plant'] == 'N101') | (base_pos_merge['Plant'] == 'R601')] = 'MCA' 
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'H5W6') | (base_pos_merge['Plant'] == 'DV02') | 
        (base_pos_merge['Plant'] == 'H501') | (base_pos_merge['Plant'] == 'H506') | 
        (base_pos_merge['Plant'] == 'H5V3') | (base_pos_merge['Plant'] == 'H508')] = 'MX'
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'H507')] = 'RD'

base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'PA62') | (base_pos_merge['Plant'] == 'BR20')] = 'BR'
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'AR20') | (base_pos_merge['Plant'] == 'PE20') | 
        (base_pos_merge['Plant'] == 'PA20') | (base_pos_merge['Plant'] == 'US38') |
        (base_pos_merge['Plant'] == 'US87') |
        (base_pos_merge['Plant'] == 'CL20') | (base_pos_merge['Plant'] == 'CO20')] = 'MCA' 
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'MX20') | (base_pos_merge['Plant'] == 'US27') | 
        (base_pos_merge['Plant'] == 'US23') | (base_pos_merge['Plant'] == 'US22')] = 'MX'
base_pos_merge['Region'].loc[(base_pos_merge['Plant'] == 'H507')] = 'RD'
    
#Country Plant Classification (Physical Location = CDO)  
## Added new plant BR18 on 06--6-2023 - Requested by Francisco    
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H509')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H5V1')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'Z402')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'BR18')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == '9401')] = 'ARG'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'AL01')] = 'PER'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'B301')] = 'PAN'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H503')] = 'MIA'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'N101')] = 'CHI'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'R601')] = 'COL'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H501')] = 'MEX'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H506')] = 'Sandston'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H508')] = 'MEX'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H5V3')] = 'MEX'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'H507')] = 'Ryder'

base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'PA62')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'BR20')] = 'BRZ'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'AR20')] = 'ARG'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'PE20')] = 'PER'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'PA20')] = 'PAN'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'US87')] = 'PAN'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'US38')] = 'MIA'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'CL20')] = 'CHI'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'CO20')] = 'COL'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'MX20')] = 'MEX'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'US27')] = 'Sandston'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'US23')] = 'San Bernadino'
base_pos_merge['Country Plant'].loc[(base_pos_merge['Plant'] == 'US22')] = 'El Paso'

#Categories Classification
lookup_value = pd.array(base_pos_merge['PL'])
base_pos_merge['Category'] = python_vlookup.vlookup(lookup_value,'PLs.csv',2 ,debug='skip', error_value="")
#base = base[base.PL!="]

#Business Group Classification
lookup_value = pd.array(base_pos_merge['PL'])
base_pos_merge['Business Group'] = python_vlookup.vlookup(lookup_value,'PLs.csv',3 ,debug='skip', error_value="")
#base = base[base.PL!=""]

#Date, Month and Quarter Classification
base_pos_merge['Month'] = month
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2017_08') | (base_pos_merge['Month'] == '2017_09') | (base_pos_merge['Month'] == '2017_10')] = "FY17Q4"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2018_11') | (base_pos_merge['Month'] == '2018_12') | (base_pos_merge['Month'] == '2018_01')] = "FY18Q1"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2018_02') | (base_pos_merge['Month'] == '2018_03') | (base_pos_merge['Month'] == '2018_04')] = "FY18Q2"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2018_05') | (base_pos_merge['Month'] == '2018_06') | (base_pos_merge['Month'] == '2018_07')] = "FY18Q3"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2018_08') | (base_pos_merge['Month'] == '2018_09') | (base_pos_merge['Month'] == '2018_10')] = "FY18Q4"    
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2018_11') | (base_pos_merge['Month'] == '2018_12') | (base_pos_merge['Month'] == '2019_01')] = "FY19Q1"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2019_02') | (base_pos_merge['Month'] == '2019_03') | (base_pos_merge['Month'] == '2019_04')] = "FY19Q2"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2019_05') | (base_pos_merge['Month'] == '2019_06') | (base_pos_merge['Month'] == '2019_07')] = "FY19Q3"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2019_08') | (base_pos_merge['Month'] == '2019_09') | (base_pos_merge['Month'] == '2019_10')] = "FY19Q4"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2019_11') | (base_pos_merge['Month'] == '2019_12') | (base_pos_merge['Month'] == '2020_01')] = "FY20Q1"    
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2020_02') | (base_pos_merge['Month'] == '2020_03') | (base_pos_merge['Month'] == '2020_04')] = "FY20Q2"    
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2020_05') | (base_pos_merge['Month'] == '2020_06') | (base_pos_merge['Month'] == '2020_07')] = "FY20Q3"    
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2020_08') | (base_pos_merge['Month'] == '2020_09') | (base_pos_merge['Month'] == '2020_10')] = "FY20Q4"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2020_11') | (base_pos_merge['Month'] == '2020_12') | (base_pos_merge['Month'] == '2021_01')] = "FY21Q1"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2021_02') | (base_pos_merge['Month'] == '2021_03') | (base_pos_merge['Month'] == '2021_04')] = "FY21Q2"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2021_05') | (base_pos_merge['Month'] == '2021_06') | (base_pos_merge['Month'] == '2021_07')] = "FY21Q3"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2021_08') | (base_pos_merge['Month'] == '2021_09') | (base_pos_merge['Month'] == '2021_10')] = "FY21Q4"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2021_11') | (base_pos_merge['Month'] == '2021_12') | (base_pos_merge['Month'] == '2022_01')] = "FY22Q1"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2022_02') | (base_pos_merge['Month'] == '2022_03') | (base_pos_merge['Month'] == '2022_04')] = "FY22Q2"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2022_05') | (base_pos_merge['Month'] == '2022_06') | (base_pos_merge['Month'] == '2022_07')] = "FY22Q3"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2022_08') | (base_pos_merge['Month'] == '2022_09') | (base_pos_merge['Month'] == '2022_10')] = "FY22Q4"
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2022_11') | (base_pos_merge['Month'] == '2022_12') | (base_pos_merge['Month'] == '2023_01')] = "FY23Q1"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2023_02') | (base_pos_merge['Month'] == '2023_03') | (base_pos_merge['Month'] == '2023_04')] = "FY23Q2"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2023_05') | (base_pos_merge['Month'] == '2023_06') | (base_pos_merge['Month'] == '2023_07')] = "FY23Q3"  
base_pos_merge['Quarter'].loc[(base_pos_merge['Month'] == '2023_08') | (base_pos_merge['Month'] == '2023_09') | (base_pos_merge['Month'] == '2023_10')] = "FY23Q4"    
#Removing records with negative Qty 
base_pos_merge = base_pos_merge[(base_pos_merge['Qty']> 0)]

#Removing values in AGE_61_90_QT with negative values
#base_pos_merge['AGE_61_90_QT'].loc[(base_pos_merge['AGE_61_90_QT'] < 0)] = 0
#base_pos_merge['AGE_61_90_AM'].loc[(base_pos_merge['AGE_61_90_AM'] < 0)] = 0

#Removing not known country Plants 
#base_pos_merge = base_pos_merge[(base_pos_merge['Plant'] != '10PA')]
#base_pos_merge = base_pos_merge[(base_pos_merge['Plant'] != '11CO')]
#base_pos_merge = base_pos_merge[(base_pos_merge['Plant'] != '11CL')]

#Removing Consumer Panama records to agrregate manual country onwer split file
#RODAR PRIMEIRO A ATUALIZAÇAO DO INVSPLIT
os.chdir('C:/Users/bmma/OneDrive - HP Inc/LATAM Inventory/Inventory WO Bklg')
PA20Split = pd.read_excel("InvSplit.xlsx", sheet_name="TempPBI", header=0)
# PLPA20 = PA20Split['PL'].unique()
SKUPA20 = PA20Split['Material'].unique()

# base_pos_merge_2 = base_pos_merge[~((base_pos_merge['Plant'] =="PA20") & 
#                                      (base_pos_merge['Business Group'] =="PS Consumer") &
#                                      (base_pos_merge['Category2'] =="Units") &
#                                      (base_pos_merge.PL.isin(PLPA20)) == True)]

# base_pos_merge_3 = base_pos_merge_2[~((base_pos_merge_2['Plant'] =="PA20") & 
#                                     (base_pos_merge_2['Business Group'] =="PS Commercial") &
#                                     (base_pos_merge_2.PL.isin(PLPA20)) == True)]


base_pos_merge_3 = base_pos_merge[~((base_pos_merge['Plant'] =="PA20") & 
                                 (base_pos_merge.Material.isin(SKUPA20)) == True)]
base_pos_merge_3 = base_pos_merge_3[~((base_pos_merge['Plant'] =="US87") & 
                                 (base_pos_merge.Material.isin(SKUPA20)) == True)]

#base_pos_merge_3[base_pos_merge_3.index.duplicated()]

#base_pos_merge_2 = base_pos_merge[(base_pos_merge['Plant'] !="PA20") & (base_pos_merge['Business Group'] !="PS Consumer") & (base_pos_merge['Category2'] !="Units")]
#base_pos_merge_2 = base_pos_merge.drop(base_pos_merge.index[(base_pos_merge['Plant'] =="PA20") & (base_pos_merge['Business Group'] =="PS Consumer") & (base_pos_merge['Category2'] =="Units")])

# Delete weekly Age buckets for SQL database
base_pos_merge_SQL = base_pos_merge.drop(['Age 0-7 Qt','Age 8-14 Qt','Age 15-21 Qt','Age 22-28 Qt',
                'Age 29-35 Qt','Age 36-42 Qt','Age 43-49 Qt','Age 50-56 Qt',
                'Age 57-63 Qt','Age 64-70 Qt','Age 71-77 Qt','Age 78-84 Qt',
                'Age 85-90 Qt','Age 121-150 Qt','Age 151-180 Qt','Age 181-210 Qt',
                'Age 211-240 Qt','Age 241-270 Qt','Age 271-300 Qt','Age 301-330 Qt',
                'Age 331-360 Qt','Age Greater 360 Qt',
                'Age 0-7 Am','Age 8-14 Am','Age 15-21 Am',
                'Age 22-28 Am','Age 29-35 Am','Age 36-42 Am','Age 43-49 Am',
                'Age 50-56 Am','Age 57-63 Am','Age 64-70 Am','Age 71-77 Am',
                'Age 78-84 Am','Age 85-90 Am','Age 121-150 Am','Age 151-180 Am',
                'Age 181-210 Am','Age 211-240 Am','Age 241-270 Am','Age 271-300 Am',
                'Age 301-330 Am','Age 331-360 Am','Age Greater 360 Am'], axis=1)

string3 = 'DETAILS_WEBI_'
escritaCSV = string3 + data_csv_Webi + string2

#Gerando o arquivo CSV
os.chdir('C:/Users/bmma/OneDrive - HP Inc/LATAM Inventory/Imported OARs Daily Files/Arquivos pos merge 41')
base_pos_merge.to_csv(escritaCSV, header = True, index = None)
base_pos_merge_SQL.to_csv('DETAILS_WEBI_SQL'+ data_csv_Webi + string2, header = True, index = None)
# base_pos_merge_2.to_csv('DETAILS_WEBI_2_' + data_csv_Webi + string2, header = True, index = None)
# base_pos_merge_2.to_csv('DETAILS_WEBI_2_BKP' + data_csv_Webi + string2, header = True, index = None)
base_pos_merge_3.to_csv('DETAILS_WEBI_3_' + data_csv_Webi + string2, header = True, index = None)
base_pos_merge_3.to_csv('DETAILS_WEBI_3_BKP' + data_csv_Webi + string2, header = True, index = None)

#Copiando o arquivo para subir no SQL DB
os.chdir('//G8W03456A.Auth.hpicorp.net/InventoryDaily/files')

#Copiando o arquivo para subir no SQL DB
#os.chdir('//G8W03456A/InventoryDaily/files')
base_pos_merge_SQL.to_csv('DETAILS_WEBI_SQL'+ data_csv_Webi + string2, header = True, index = None)

# #Rodar se não tive o country onwer split de consumer Panama
# os.chdir('C:/Users/rappra/OneDrive - HP Inc/LATAM Inventory/Inventory WO Bklg')
# base_pos_merge.to_csv('DETAILS_WEBI.csv', header = True, index = None)

checkRegion_Owner       = base_pos_merge.apply(lambda x: True if x['Country'] == '' and x['Plant'] != 'US22' and x['Plant'] != 'US23' and x['Plant'] != 'US27' else False , axis=1)
checkCategory           = base_pos_merge.apply(lambda x: True if x['Category'] == '' else False , axis=1)
checkBusinessGroup      = base_pos_merge.apply(lambda x: True if x['Business Group'] == '' or x['Business Group'] == "Other" else False , axis=1)
checkCP                 = base_pos_merge.apply(lambda x: True if x['Country Plant'] == '' else False , axis=1)
#checkDescription        = base_pos_merge.apply(lambda x: True if x['Material Description'] == '' else False, axis=1)
checkAged_NegativesQT   = base_pos_merge.apply(lambda x: True if x['AGE_61_90_QT'] < 0 else False , axis=1)
checkAged_NegativesAM   = base_pos_merge.apply(lambda x: True if x['AGE_61_90_AM'] < 0 else False , axis=1)
check_NegativesQT   = base_pos_merge.apply(lambda x: True if x['Qty'] < 0 else False , axis=1)
check_NegativesAM   = base_pos_merge.apply(lambda x: True if x['Cost'] < 0 else False , axis=1)

#len(np.where(pd.isnull(base_pos_merge['Material Description'])))
#len(base_pos_merge[base_pos_merge['Material Description'] == '']) 
#base_pos_merge['Material Description'].isnull().sum()

numOfRowsRegion_Owner        = len(checkRegion_Owner[checkRegion_Owner == True].index)
numOfRowsCategory            = len(checkCategory[checkCategory == True].index)
numOfRowsBusinessGroup       = len(checkBusinessGroup[checkBusinessGroup == True].index)
numOfRowsCP                  = len(checkCP[checkCP == True].index)
#numOfRowsDescription         = len(checkDescription[checkDescription == True].index)
numOfRowsDescription         = base_pos_merge['Material Description'].isnull().sum()
numOfNegativeAgedQT          = len(checkAged_NegativesQT[checkAged_NegativesQT == True].index)                                       
numOfNegativeAgedAM          = len(checkAged_NegativesAM[checkAged_NegativesAM == True].index)    
numOfNegativeQT              = len(check_NegativesQT[checkAged_NegativesQT == True].index)                                       
numOfNegativeAM              = len(check_NegativesAM[checkAged_NegativesAM == True].index)                               

options = ['', 'Other'] 
rslt_df = base_pos_merge[base_pos_merge['Business Group'].isin(options)] 
#rslt5_df = base_pos_merge[base_pos_merge['PL'].isin(options)] 
#rslt5_df['PL'].unique()
rslt5_df = base_pos_merge[(base_pos_merge['Business Group'] =="PS Consumer") &
                          (base_pos_merge['Category2'] =="Units") &
                          base_pos_merge['Plant'].isin(['PA20','US87'])] 

options = [''] 
rslt2_df = base_pos_merge[((base_pos_merge['Country'].isin(options) == True) & (base_pos_merge['Plant'] != 'US22') & (base_pos_merge['Plant'] != 'US23') & (base_pos_merge['Plant'] != 'US27'))] 
rslt3_df = base_pos_merge[((base_pos_merge['Country'].isin(options) == True) & (base_pos_merge['Plant'] != 'US22') & (base_pos_merge['Plant'] != 'US23') & (base_pos_merge['Plant'] != 'US27'))] 
rslt4_df = base_pos_merge[((base_pos_merge['Country Plant'].isin(options) == True) & (base_pos_merge['Plant'] != 'US22') & (base_pos_merge['Plant'] != 'US23') & (base_pos_merge['Plant'] != 'US27'))] 

print('\nNumber of Rows in dataframe in which Country is blank: ', numOfRowsRegion_Owner) 
print('Number of Rows in dataframe in which Category is blank: ', numOfRowsCategory)
print('Number of Rows in dataframe in which Business Group is blank or Other: ', numOfRowsBusinessGroup)
print('Number of Rows in dataframe in which Country Plant is blank: ', numOfRowsCP)
print('Number of Rows in dataframe in which Material Description is blank: ', numOfRowsDescription)
print('\nResult dataframe of Plants which Country is blank :\n', rslt2_df['Plant'].unique())
print('\nResult dataframe of Business Group which Country is blank:\n', rslt3_df['Business Group'].unique())
print('\nResult dataframe of Storage Location which Country is blank:\n', rslt3_df['StorageLoc'].unique())
print('Number of Rows in dataframe in which Qty < 0 :', numOfNegativeQT)
print('Number of Rows in dataframe in which Cost < 0 :', numOfNegativeAM)
